# %% [markdown]
# <a href="https://colab.research.google.com/github/Gjesuss/code_a_toy_generation/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
list_pets = ["Meg", "Duda", "Pandora", "Joy", "Garoa", "Mini",
             "Soneca", "Honda", "Lucky", "Bingo"]

# Sorteando o nome do PET
sorteioPets = random.choice(list_pets)

# Descobrindo a posição do PET
indice_do_pet = list_pets.index(sorteioPets)

# Usando o pop passando o indice
list_pets.pop(indice_do_pet)

print(f"Pet sorteado e removido: {sorteioPets}")
print(f"Total de pets restantes na lista: {len(list_pets)}")
print(f"Lista atualizada: {list_pets}")
# Out:
# Pet sorteado e removido: Pandora
# Total de pets restantes na lista: 9
# Lista atualizada: ['Meg', 'Duda', 'Joy', 'Garoa', 'Mini', 'Soneca', 'Honda', 'Lucky', 'Bingo']
